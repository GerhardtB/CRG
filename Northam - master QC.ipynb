# %% [markdown]
# <h1>Northam master QC<span class="tocSkip"></span></h1>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-libraries-and-functions-" data-toc-modified-id="Load-libraries-and-functions--1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load libraries and functions <a name="libraries"></a></a></span></li><li><span><a href="#Loading-Google-sheet" data-toc-modified-id="Loading-Google-sheet-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Loading Google sheet</a></span></li><li><span><a href="#Defaults-and-functions" data-toc-modified-id="Defaults-and-functions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Defaults and functions</a></span><ul class="toc-item"><li><span><a href="#Visualization-functions" data-toc-modified-id="Visualization-functions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Visualization functions</a></span></li><li><span><a href="#Some-examples-of-exploratory-tests" data-toc-modified-id="Some-examples-of-exploratory-tests-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Some examples of exploratory tests</a></span></li></ul></li><li><span><a href="#Importing-and-formatting-Northam-data-" data-toc-modified-id="Importing-and-formatting-Northam-data--4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Importing and formatting Northam data <a id="importingNortham"></a></a></span><ul class="toc-item"><li><span><a href="#Exploring-the-Northam-data-directory-" data-toc-modified-id="Exploring-the-Northam-data-directory--4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Exploring the Northam data directory <a id="exploringNortham"></a></a></span></li><li><span><a href="#Importing-and-formatting-the-logger-data-" data-toc-modified-id="Importing-and-formatting-the-logger-data--4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Importing and formatting the logger data <a id="importingNorthamLogger"></a></a></span></li><li><span><a href="#Troubleshoot-problematic-files" data-toc-modified-id="Troubleshoot-problematic-files-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Troubleshoot problematic files</a></span></li><li><span><a href="#Overview-of-raw-logger-data" data-toc-modified-id="Overview-of-raw-logger-data-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Overview of raw logger data</a></span></li><li><span><a href="#Importing-and-formatting-eBam-data-(Northam-site)-" data-toc-modified-id="Importing-and-formatting-eBam-data-(Northam-site)--4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Importing and formatting eBam data (Northam site) <a id="exploringImportingeBam"></a></a></span><ul class="toc-item"><li><span><a href="#Exploring-the-eBam-data-directory-" data-toc-modified-id="Exploring-the-eBam-data-directory--4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Exploring the eBam data directory <a id="exploringeBam"></a></a></span></li><li><span><a href="#Importing-and-formatting-the-PM10-eBam-data-" data-toc-modified-id="Importing-and-formatting-the-PM10-eBam-data--4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Importing and formatting the PM10 eBam data <a id="importingeBam"></a></a></span></li><li><span><a href="#Importing-and-formatting-PM2.5-eBam-data" data-toc-modified-id="Importing-and-formatting-PM2.5-eBam-data-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Importing and formatting PM2.5 eBam data</a></span></li></ul></li></ul></li><li><span><a href="#Quality-control" data-toc-modified-id="Quality-control-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Quality control</a></span><ul class="toc-item"><li><span><a href="#Set-up-QC-variables" data-toc-modified-id="Set-up-QC-variables-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Set up QC variables</a></span></li><li><span><a href="#Apply-documented-problems" data-toc-modified-id="Apply-documented-problems-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Apply documented problems</a></span></li><li><span><a href="#Line/battery-voltage-" data-toc-modified-id="Line/battery-voltage--5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Line/battery voltage <a id="lbVqc"></a></a></span></li><li><span><a href="#Data-quality-control-and-assurance-on-eBam-" data-toc-modified-id="Data-quality-control-and-assurance-on-eBam--5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Data quality control and assurance on eBam <a id="qcac"></a></a></span><ul class="toc-item"><li><span><a href="#PM10-eBam" data-toc-modified-id="PM10-eBam-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>PM10 eBam</a></span></li><li><span><a href="#PM-logged-on-the-logger" data-toc-modified-id="PM-logged-on-the-logger-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>PM logged on the logger<a id="pmqc"></a></a></span></li><li><span><a href="#SO2-" data-toc-modified-id="SO2--5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>SO2 <a id="SO2qc"></a></a></span></li><li><span><a href="#O3-" data-toc-modified-id="O3--5.4.4"><span class="toc-item-num">5.4.4&nbsp;&nbsp;</span>O3 <a id="O3qc"></a></a></span></li><li><span><a href="#NO-" data-toc-modified-id="NO--5.4.5"><span class="toc-item-num">5.4.5&nbsp;&nbsp;</span>NO <a id="NOqc"></a></a></span></li><li><span><a href="#CO-" data-toc-modified-id="CO--5.4.6"><span class="toc-item-num">5.4.6&nbsp;&nbsp;</span>CO <a id="coqc"></a></a></span></li><li><span><a href="#Wind-speed-and--direction-" data-toc-modified-id="Wind-speed-and--direction--5.4.7"><span class="toc-item-num">5.4.7&nbsp;&nbsp;</span>Wind speed and -direction <a id="wswd"></a></a></span></li></ul></li><li><span><a href="#Merging-and-exporting-the-3-data-streams--" data-toc-modified-id="Merging-and-exporting-the-3-data-streams---5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Merging and exporting the 3 data streams  <a id="mergeExportStreams"></a></a></span><ul class="toc-item"><li><span><a href="#Merging-the-data-" data-toc-modified-id="Merging-the-data--5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Merging the data <a id="mergeStreams"></a></a></span></li></ul></li><li><span><a href="#Data-visualizaton-" data-toc-modified-id="Data-visualizaton--5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Data visualizaton <a id="visualization"></a></a></span><ul class="toc-item"><li><span><a href="#Wind-rose" data-toc-modified-id="Wind-rose-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Wind rose</a></span></li></ul></li><li><span><a href="#Data-exploration-and-statistics-" data-toc-modified-id="Data-exploration-and-statistics--5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Data exploration and statistics <a id="explore"></a></a></span></li><li><span><a href="#Source-Apportionment-Met-Data-Spring" data-toc-modified-id="Source-Apportionment-Met-Data-Spring-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Source Apportionment Met Data Spring</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Load libraries and functions <a name="libraries"></a>

# %%
import glob
# The pandas data science library that gives a 'spreadsheet'-like capabilities to python
import pandas as pd
# The matplotlih library is used to visualize data
import matplotlib.pyplot as plt
# The pathlib library is used to manage access to disk. It helps us to keep things the same between Windows and Linux
from pathlib import Path
# The os library is used to list and access files and directories on the hard drive
import os
# Numpy is the numerical library. It is used by many of the ones before, but we import it for in case
import numpy as np
# From Numpy we also import the nan 'missing-value' object that we use alot
from numpy import nan
# For fancy matching of strings, we use re
import re
# String libary for temporary file import
from io import StringIO
# Create tooltips for interactive plots
import mpld3
# For connect to google sheet
import gspread
from oauth2client.service_account import ServiceAccountCredentials

from scipy import interpolate
from windrose import WindroseAxes
import matplotlib.gridspec as gridspec
import matplotlib.style
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import matplotlib.cm as cm
from datetime import datetime

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
# This 'widget' is used to give us interactive graph capabilities in the matplotlib figures
# %matplotlib widget

# %% [markdown]
# # Loading Google sheet

# %%
# Configure the connection 
scope = ['https://spreadsheets.google.com/feeds']

# Give the path to the Service Account Credential json file 
# 1. Go to Google Development Console (https://console.developers.google.com/project)
# 2. Create new project
# 3. Go to “APIs & Services > Credentials” and choose “Create credentials > Service account key”.
# 4. Fill out the form
# 5. Click “Create key”
# 6. Select “JSON” and click “Create”

credentials = ServiceAccountCredentials.from_json_keyfile_name('key/crgprojects-b66f872bd816.json',
                                                               scope)
# Authorise your Notebook
gc = gspread.authorize(credentials)

# The sprad sheet ID, which can be taken from the link to the sheet
#https://docs.google.com/spreadsheets/d/1Fe1P2QEiCjl7KK6YEckzGLC_VqOuGtaChaDGbn2SOhE/edit?usp=sharing
#spreadsheet_key = '1pwJDzIl1O8gQSHD8SekW6442rrLRgLVTYA90dQb7chg'
spreadsheet_key = '1Fe1P2QEiCjl7KK6YEckzGLC_VqOuGtaChaDGbn2SOhE'

#Opening the worksheet by using Worksheet ID
def readSheet():
    workbook = gc.open_by_key(spreadsheet_key)#Selecting which sheet to pulling the data
    reports = workbook.worksheet('Instrument Failure report')#Pulling the data and transform it to the data frame
    values = reports.get_all_values()
    Reports = pd.DataFrame(values[1:], columns=values[0])
    Reports=Reports[Reports['What is the site']=='Northam AQMS']
    return(reports,Reports)
reports, Reports = readSheet()

# %%
Reports
# Out:
#               Timestamp What is the site Which instrument failed?  \
# 7   12/04/2020 12:00:00     Northam AQMS                 O3 (ppb)
# 8     2/8/2021 17:03:19     Northam AQMS                 O3 (ppb)
# 9     2/8/2021 17:14:23     Northam AQMS                 CO (ppm)
# 10    2/8/2021 17:29:40     Northam AQMS                 CO (ppm)
# 13   1/26/2021 16:31:50     Northam AQMS             PM10 (ug/m3)
# 14   1/26/2021 16:31:50     Northam AQMS            PM2.5 (ug/m3)
# 15   1/26/2021 16:31:50     Northam AQMS             PM10 (ug/m3)
# 16   1/26/2021 16:31:50     Northam AQMS            PM2.5 (ug/m3)
# 17   1/26/2021 16:31:50     Northam AQMS                SO2 (ppb)
# 18   1/26/2021 16:31:50     Northam AQMS                SO2 (ppb)
# 19   1/26/2021 16:31:50     Northam AQMS                SO2 (ppb)
# 20   1/26/2021 16:31:50     Northam AQMS                SO2 (ppb)
# 21   1/26/2021 16:31:50     Northam AQMS                SO2 (ppb)
# ...

# %% [markdown]
# # Defaults and functions

# %% [markdown]
# Some useful functions

# %%
def head(filename,N=10):
    n=0
    with open(Path(filename)) as fp:
        for l in fp.readlines():
            if n<N:
                print(l,end="")
                n=n+1
                
def tail(filename,N=10):
    n=0
    with open(Path(filename)) as fp:
        lines=[i for i in fp.readlines()]
        Nlines=len(lines)
        for l in lines[Nlines-N:]:
            if n<N:
                print(l,end="")
                n=n+1
                
def ConvertNumeric(df,var):
    df[var]= pd.to_numeric(df[var],errors='coerce')

def testLogger(filename):
    Sep=","
    Data=[]
    with open(filename) as fp:
        for line in fp.readlines():
            row=line.split(Sep)
            Data.append(len(row))
    print(pd.DataFrame({"Columns":Data}).describe())
    
def ncolumnsLogger(filename):
    Sep=","
    Data=[]
    with open(filename) as fp:
        for line in fp.readlines():
            row=line.split(Sep)
            Data.append(len(row))
    return(np.median(np.array(Data)))

def readLogger(filename, nLines=18):
    DataString=""
    Sep=","
    with open(filename) as fp:
        for line in fp.readlines():
            row=line.split(Sep)
            if isinstance(nLines, list):
                if len(row) in nLines and re.match('\W*(\d{4})[/.-](\d{2})[/.-](\d{2})\s{1}(\d{2}):(\d{2}):(\d{2})\W*',row[0]):
                    DataString=DataString+line                
            else:
                if len(row) == nLines and re.match('\W*(\d{4})[/.-](\d{2})[/.-](\d{2})\s{1}(\d{2}):(\d{2}):(\d{2})\W*',row[0]):
                    DataString=DataString+line
    return(DataString)

def readRM(filename, nLines=18):
    DataString=""
    Sep=","
    with open(filename) as fp:
        for line in fp.readlines():
            row=line.split(Sep)
            if len(row) == nLines and re.match('\W*(\d{4})[/.-](\d{2})[/.-](\d{2})\s{1}(\d{2}):(\d{2}):(\d{2})\W*',row[0]):
                DataString=DataString+line
    return(DataString)

def lsR(dir,pattern=".csv",prefix="",postfix=""):
    list=[]
    for path,dirs,files in os.walk(Path(dir)):
        for f in files:
            if f.count(pattern) > 0 and f.startswith(prefix) and f.endswith(postfix):
                list.append(os.path.join(path,f))
    return(list)

# %% [markdown]
# Default directories

# %%
HomeDir=Path('/home/roelof/Dropbox (NWU)')
DataDir = Path(HomeDir / 'CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns')
FinalDataDir=Path(HomeDir / 'CRG_Projects/01_Research_Campaigns/Anglo_SA/03_FinalData')

# %% [markdown]
# ## Visualization functions

# %%
def plotdiurnalstats(df,var='PM10_logger (ug/m3)'):
    df['Time'] = df.index.map(lambda x: x.strftime("%H:00"))
    diurnal = df[['Time',var]].groupby('Time').describe()[var]
    fig, ax = plt.subplots(1, figsize=(7,6))
    ax.set_ylabel(var, fontsize=14, weight='bold')                                                                                                                                                                                                                           
    ax.set_xlabel('Time of Day', fontsize=14)                                                                                                                                                                                                                                    
    print("Plotting mean")                                                                                                                                                                                                                                                       
    ax.plot(diurnal.index, diurnal['50%'], 'g', linewidth=2.0,label=var)
    print("Plotting 75%")                                                                                                                                                                                                                                                        
    ax.plot(diurnal.index, diurnal['75%'], color='g')                                                                                                                                                                                                                            
    print("Plotting 25%")                                                                                                                                                                                                                                                        
    ax.plot(diurnal.index, diurnal['25%'], color='g') 
    ax.fill_between(diurnal.index, diurnal['50%'], diurnal['75%'], alpha=.25, facecolor='g')                                                                                                                                                                                      
    ax.fill_between(diurnal.index, diurnal['50%'], diurnal['25%'], alpha=.25, facecolor='g') 
    ax.set_xlim(0, 23);                                                                                                                                                                                                                                                          
    ax.set_xticks([i for i in range(0,24,3)])  
    plt.tight_layout() 
    
def plotdiurnal(df,var='PM10_logger (ug/m3)'):
    df['decimalhour'] = df.index.hour+(df.index.minute/60)
    
    fig, ax = plt.subplots(figsize=(7,6))
    ax.set_ylabel(var, fontsize=14, weight='bold')                                                                                                                                                                                                                           
    ax.set_xlabel('Time of Day', fontsize=14)    
    
    ax.plot(df['decimalhour'].values, df[var].values, 'o', markersize=2, linewidth=0, label=var, alpha=0.3)

    #def format_coord(x, y):
    #    z=np.array_str(df[(df['decimalhour']==x)&(df[var]==y)].index.map(lambda x: x.strftime("%y/%m/%d %H:%M")).values)[1:34]
    #    return('x={}, y={}, date={}'%(x, y,z))

    #ax.format_coord = format_coord
    
    ax.set_xlim(0, 23);                                                                                                                                                                                                                                                          
    ax.set_xticks([i for i in range(0,24,3)])  
    plt.tight_layout() 
    df.drop(['decimalhour'], axis = 1)
    
def plottimeseries(df,var='PM10_logger (ug/m3)'):
    fig, ax = plt.subplots(1,figsize=(7,6))
    df[[var]].plot(ax=ax)
    ax.set_ylabel(var, fontsize=14, weight='bold')                                                                                                                                                                                                                           
    ax.set_xlabel('', fontsize=14)            
    
#plottimeseries(df1)

# %% [markdown]
# ## Some examples of exploratory tests

# %% [markdown]
# How to check for a valid date

# %%
datestring="2020-07-30 16:29:00"
mat=re.match('(\d{4})[/.-](\d{2})[/.-](\d{2})\s{1}(\d{2}):(\d{2}):(\d{2})', datestring)
if mat is not None:
    print("is a date")
# Out:
# is a date

# %%
os.listdir(Path(DataDir / 'Northam - Main AQMS/Logger Data/20210615' ))
# Out:
# ['CR1000_Northam_Table1.dat']

# %%
lsR(Path(DataDir / 'Northam - Main AQMS/Logger Data'),"Table1",postfix=".dat")
# Out:
# ['/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20200902/CR1000_Northam_Table1_2020_08_27_16_06_2020_09_02_09_14_40.dat',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20201214/CR1000_Northam_Table1_2020_09_29_10_17_2020_12_14_15_10_49.dat',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20201111/CR1000_Northam_Table1_2020_11_11_11_08_33.dat',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20201126/CR1000_Northam_Table1_2020_11_26_09_48_15.dat',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20210615/CR1000_Northam_Table1.dat',
# ...

# %%
ncolumnsLogger(Path(DataDir / 'Rustenburg - Main AQMS/Logger Data/20200918/CR1000_Rustenburg_AngloSA_Table1_2020_09_18_07_50_2020_09_18_07_54_55.dat'))
# Out:
# 20.0

# %%
Northam_StartDate='2020-07-31'

# %% [markdown]
# # Importing and formatting Northam data <a id="importingNortham"></a>
# [Go to the top](#top)

# %% [markdown]
# ## Exploring the Northam data directory <a id="exploringNortham"></a>

# %%
os.listdir(DataDir)
# Out:
# ['GM_All_Locations',
#  'Northam - Main AQMS',
#  'Road Traffic Nata - NOVA',
#  'ES642-data.csv',
#  'ANGLO SA Project - Coordinates.kml',
#  'ES642 - All Locations',
#  '03_3032_ASA_Winter',
#  'Rustenburg - Main AQMS',
#  'Anglo SA AQMS - Field Logs.xlsx',
#  'Northam-test.csv',
#  '02_2021_ASA_Autumn',
#  '01_2020_ASA_Spring',
#  'ES642-summary.csv',
#  'ES642']

# %%
np.sort(os.listdir(Path(DataDir / 'Northam - Main AQMS/Logger Data' )))
# Out:
# array(['20200813', '20200821', '20200827', '20200902', '20200910',
#        '20200918', '20200923', '20200929', '20201007', '20201017',
#        '20201023', '20201029', '20201104', '20201111', '20201118',
#        '20201126', '20201204', '20201214', '20210113', '20210120',
#        '20210128', '20210211', '20210222', '20210309', '20210318',
#        '20210331', '20210408', '20210423', '20210504', '20210511',
#        '20210519', '20210601', '20210601_Ecostat.csv', '20210609',
#        '20210615', '20210621', '20210725', '20210805', '20210812',
#        '20210819', '20210901'], dtype='<U20')

# %% [markdown]
# 18 fields
# 4 header lines

# %%
d=readLogger(Path(DataDir / 'Northam - Main AQMS/Logger Data/20200827/CR1000_Northam_Table1_2020_08_27_16_06.dat'))

# %%
d[:1000]
# Out:
# '"2020-07-30 16:29:00",107,0.31,0.31,245,0,26.9,25.13,18.43,0,12.62918,-1.340876,1.340876,2.681753,6.704382,-1.772268,209.3779,31.08706\n"2020-07-30 16:30:00",108,0.86,0.333,192.1,71.41,26.85,25.15,18.22,0,12.62918,0.782183,1.452625,2.681768,6.704422,-2.331083,209.4462,31.08706\n"2020-07-30 16:31:00",109,1.71,0.387,187.2,92.3,26.78,25.18,18.29,0,12.62918,0.558709,1.340902,2.681804,6.70451,-1.772629,209.4657,31.09309\n"2020-07-30 16:32:00",110,0.86,0.373,120,79.92,26.85,25.17,18.36,0,12.62918,0.558714,1.340913,2.570085,6.704567,-2.219761,209.568,31.12321\n"2020-07-30 16:33:00",111,0.58,0.389,47.46,86.4,26.91,25.19,18.08,0,12.62735,-0.1117431,1.34092,3.464045,6.704603,-2.331604,209.5859,31.09911\n"2020-07-30 16:34:00",112,0.96,0.279,345.3,93.3,26.84,25.17,17.87,0,12.62781,0.5586941,1.340857,4.022572,6.704287,-2.33069,209.576,31.07577\n"2020-07-30 16:35:00",113,1.25,0.515,9.67,38.15,26.78,25.12,17.87,0,12.62735,1.291434E-006,1.340875,4.022624,6.704373,-2.442681,209.5787,31.05317\n"2020-
# ...

# %%
#List the logger files in the tree
sorted(lsR(Path(DataDir / 'Northam - Main AQMS/Logger Data'),"Table1"))
# Out:
# ['/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20200813/CR1000_Northam_Table1_2020_08_13_15_07_21.dat',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20200821/CR1000_Northam_Table1_2020_08_21_13_48_46.dat',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20200827/CR1000_Northam_Table1_2020_08_27_16_06.dat',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20200902/CR1000_Northam_Table1_2020_08_27_16_06_2020_09_02_09_14_40.dat',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20200910/CR1000_Northam_Table1_2020_09_10_12_38_2020_09_10_13_04_26.dat',
# ...

# %% [markdown]
# ## Importing and formatting the logger data <a id="importingNorthamLogger"></a>

# %%
Northam_StartDate='2020-07-31'

# %%
LoggerVariables=["TIMESTAMP","RECORD","Wind_Speed_Max (m/s)","Wind_Speed_Std (m/s)","Wind_Direction (deg)","Wind_Direction_Std (deg)","Temperature (degC)","Ambient_Temperature (degC)","Relative_Humidity (%)","Rainfall (mm)","Battery_Voltage (V)","SO2 (ppb)","NO (ppb)","NO2 (ppb)","O3 (ppb)","CO (ppm)","Line_Voltage (V)","Logger_Temperature (degC)","PM10 (ug/m3)","PM2.5 (ug/m3)"]
df1=pd.DataFrame()
for path,dirs,files in os.walk(Path(DataDir / 'Northam - Main AQMS/Logger Data' )):
    for f in files:
        fullpath = os.path.join(path,f)
        if f.count("Table1") > 0:
            print(f)
            Data = readLogger(fullpath,[18, 20])  
            if len(Data) > 0:
                ncols = len(Data.split('\n')[0].split(","))
                if ncols == 20:
                    LoggerVariables=["TIMESTAMP","RECORD","Wind_Speed_Max (m/s)","Wind_Speed_Std (m/s)","Wind_Direction (deg)","Wind_Direction_Std (deg)","Temperature (degC)","Ambient_Temperature (degC)","Relative_Humidity (%)","Rainfall (mm)","Battery_Voltage (V)","SO2 (ppb)","NO (ppb)","NO2 (ppb)","O3 (ppb)","CO (ppm)","Line_Voltage (V)","Logger_Temperature (degC)","PM10_logger (ug/m3)","PM2.5_logger (ug/m3)"]
                elif ncols == 18:
                    LoggerVariables=["TIMESTAMP","RECORD","Wind_Speed_Max (m/s)","Wind_Speed_Std (m/s)","Wind_Direction (deg)","Wind_Direction_Std (deg)","Temperature (degC)","Ambient_Temperature (degC)","Relative_Humidity (%)","Rainfall (mm)","Battery_Voltage (V)","SO2 (ppb)","NO (ppb)","NO2 (ppb)","O3 (ppb)","CO (ppm)","Line_Voltage (V)","Logger_Temperature (degC)"]              
                dftmp = pd.read_csv(StringIO(Data), parse_dates=[0], index_col=0,names=LoggerVariables, na_values=["NAN"])    
                if len(df1) == 0:
                    #print("initialize")
                    df1 = dftmp
                else:
                    #print(dftmp.tail)
                    df1 = df1.combine_first(dftmp)
                    
df1.index.name="Date"
df1.drop(columns=['RECORD'],inplace=True)
df1=df1[Northam_StartDate:]
# Out:
# CR1000_Northam_Table1_2020_08_27_16_06_2020_09_02_09_14_40.dat
# CR1000_Northam_Table1_2020_09_29_10_17_2020_12_14_15_10_49.dat
# CR1000_Northam_Table1_2020_11_11_11_08_33.dat
# CR1000_Northam_Table1_2020_11_26_09_48_15.dat
# CR1000_Northam_Table1.dat
# CR1000_Northam_Table1_2020_09_29_10_17_2020_10_07_09_52_11.dat
# CR1000_Northam_Table1_2020_10_23_13_17_37.dat
# CR1000_Northam_Table1_2020_09_18_12_02_2020_09_23_12_03_58.dat
# CR1000_Northam_Table1.dat
# CR1000_Northam_Table1_2020_08_21_13_48_46.dat
# CR1000_Northam_Table1_2021_01_20_11_10_17.dat
# CR1000_Northam_Table1.dat
# CR1000_Northam_Table1_2020_08_27_16_06.dat
# CR1000_Northam_Table1_2020_08_13_15_07_21.dat
# CR1000_Northam_Table1_2020_12_04_08_53_51.dat
# CR1000_Northam_Table1_2020_11_04_11_03_46.dat
# CR1000_Northam_Table1_2020_09_18_12_02_2020_09_18_12_03_12.dat
# CR1000_Northam_Table1_2020_09_29_10_17_2021_05_11_11_40_02.dat
# CR1000_Northam_Table1_2021_01_13_09_35_43.dat
# CR1000_Northam_Table1.dat
# ...

# %% [markdown]
# ## Troubleshoot problematic files

# %% [markdown]
# Use the next cell to troubleshoot problematic files.

# %%
checkfile='CR1000_Northam_Table1_2020_09_29_10_17_2020_10_07_09_52_11.dat'

fullpath=lsR(Path(DataDir / 'Northam - Main AQMS/Logger Data'),checkfile)
Data = readLogger(fullpath[0],[18, 20]) 
ncols = len(Data.split('\n')[0].split(","))
if ncols == 20:
    LoggerVariables=["TIMESTAMP","RECORD","Wind_Speed_Max (m/s)","Wind_Speed_Std (m/s)","Wind_Direction (deg)","Wind_Direction_Std (deg)","Temperature (degC)","Ambient_Temperature (degC)","Relative_Humidity (%)","Rainfall (mm)","Battery_Voltage (V)","SO2 (ppb)","NO (ppb)","NO2 (ppb)","O3 (ppb)","CO (ppm)","Line_Voltage (V)","Logger_Temperature (degC)","PM10 (ug/m3)_logger","PM2.5 (ug/m3)_logger"]
elif ncols == 18:
    LoggerVariables=["TIMESTAMP","RECORD","Wind_Speed_Max (m/s)","Wind_Speed_Std (m/s)","Wind_Direction (deg)","Wind_Direction_Std (deg)","Temperature (degC)","Ambient_Temperature (degC)","Relative_Humidity (%)","Rainfall (mm)","Battery_Voltage (V)","SO2 (ppb)","NO (ppb)","NO2 (ppb)","O3 (ppb)","CO (ppm)","Line_Voltage (V)","Logger_Temperature (degC)"]              
dftmp = pd.read_csv(StringIO(Data), parse_dates=[0], index_col=0,names=LoggerVariables, na_values=["NAN"])    
dftmp.info()
dftmp['Wind_Speed_Max (m/s)']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 59200 entries, 2020-08-26 09:44:00 to 2020-10-07 09:52:00
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RECORD                      59200 non-null  int64
#  1   Wind_Speed_Max (m/s)        59198 non-null  float64
#  2   Wind_Speed_Std (m/s)        59198 non-null  float64
#  3   Wind_Direction (deg)        59200 non-null  float64
#  4   Wind_Direction_Std (deg)    59200 non-null  float64
#  5   Temperature (degC)          59198 non-null  float64
#  6   Ambient_Temperature (degC)  59200 non-null  float64
#  7   Relative_Humidity (%)       59200 non-null  float64
#  8   Rainfall (mm)               59200 non-null  float64
#  9   Battery_Voltage (V)         59200 non-null  float64
#  10  SO2 (ppb)                   59200 non-null  float64
#  11  NO (ppb)                    59200 non-null  float64
# ...

# %%
tail('/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20210601/CR1000_Northam_Table1.dat')
# Out:
# "2021-05-19 08:45:00",322343,1.06,0.806,109,24.81,18.11,17.25,70.08,0,13.35345,4.587803,-286.1223,-526.9261,19.58209,-14.52991,214.105,19.45531,999.5817,12.17447
# "2021-05-19 08:46:00",322344,0.78,0.481,138.7,65.55,18.51,17.33,70.47,0,13.34841,5.259133,-275.0414,-516.0663,20.02946,-14.50178,214.0019,19.49711,999.5484,11.54771
# "2021-05-19 08:47:00",322345,0.54,0.364,119.6,42.46,18.57,17.56,69.54,0,13.36398,5.259094,-270.6756,-510.1322,19.80553,-14.35621,213.8997,19.53853,999.5413,11.65953
# "2021-05-19 08:48:00",322346,0.47,0.33,259.8,53.02,19.33,17.64,68.84,0,13.36398,5.370966,-274.5907,-514.0463,20.14113,-14.3002,213.8988,19.57618,999.5594,11.92802
# "2021-05-19 08:49:00",322347,1.28,0.743,163.9,29.17,17.77,17.52,69.46,0,13.35253,5.706638,-272.1283,-515.7234,19.35781,-14.33373,213.8982,19.61346,999.5345,12.30843
# "2021-05-19 08:50:00",322348,1.26,0.81,178.8,21.05,17.73,17.44,69.88,0,13.36948,4.811471,-258.7005,-509.6803,19.80536,-14.36728,213.8979,19.64848,999.5328,12.62172
# ...

# %%
tail( '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/Logger Data/20210609/CR1000_Northam_Table1.dat')
# Out:
# "2021-06-08 08:45:00",351143,0.8,0.433,145.9,16.7,12.19,9.75,79,0,13.6323,2.124838,-1.342012,2.684023,20.68935,-15.1144,213.9837,23.95931,12.32413,-75.64472
# "2021-06-08 08:46:00",351144,1.03,0.677,179.5,18.37,12,9.83,78.66,0,13.62498,2.236593,-1.118304,2.68392,20.1294,-14.91253,213.9755,23.99528,13.06174,-75.88783
# "2021-06-08 08:47:00",351145,1.42,1.002,163,7.107,11.54,9.87,78.45,0,13.63779,2.460241,-0.2236562,2.6839,20.46474,-14.81736,213.9739,24.01335,14.80618,-76.04383
# "2021-06-08 08:48:00",351146,1.47,1.037,163.8,10.79,11.57,9.94,78.33,0,13.63322,2.236578,0,2.46024,20.24104,-14.89562,213.9736,24.04027,17.7137,-75.97661
# "2021-06-08 08:49:00",351147,1.18,0.943,146.5,17.66,11.98,9.96,77.92,0,13.61216,2.907457,0,1.453727,20.12855,-15.09082,213.9497,24.0672,20.44166,-75.90699
# "2021-06-08 08:50:00",351148,1.03,0.921,155.1,15.31,11.88,9.96,77.97,0,13.62681,2.795572,0,2.683752,20.46361,-14.9731,213.8112,24.07454,21.53711,-75.7489
# ...

# %% [markdown]
# LoggerVariables=["TIMESTAMP","RECORD","Wind_Speed_Max (m/s)","Wind_Speed_Std (m/s)","Wind_Direction (deg)","Wind_Direction_Std (deg)","Temperature (degC)","Ambient_Temperature (degC)","Relative_Humidity (%)","Rainfall (mm)","Battery_Voltage (V)","SO2 (ppb)","NO (ppb)","NO2 (ppb)","O3 (ppb)","CO (ppm)","Line_Voltage (V)","Logger_Temperature (degC)"]
#
# df1=pd.DataFrame() for f in lsR(Path(DataDir / 'Northam - Main AQMS/Logger Data'),"Table1"): Data = readLogger(f)
# dftmp = pd.read_csv(StringIO(Data), parse_dates=[0], index_col=0,names=LoggerVariables)
# if len(df1) == 0: df1 = dftmp else: df1 = df1.combine_first(dftmp) df1.index.name="Date" df1.drop(columns=['RECORD'],inplace=True) df1=df1[Northam_StartDate:]

# %%
df1.tail()
# Out:
#                      Ambient_Temperature (degC)  Battery_Voltage (V)  \
# Date
# 2021-08-19 09:56:00                       21.71             13.06182
# 2021-08-19 09:57:00                       22.05             13.06386
# 2021-08-19 09:58:00                       22.40             13.08600
# 2021-08-19 09:59:00                       22.65             13.07866
# 2021-08-19 10:00:00                       22.54             13.06109
#
#                      CO (ppm)  Line_Voltage (V)  Logger_Temperature (degC)  \
# Date
# 2021-08-19 09:56:00 -10.66472          208.6663                   30.22723
# 2021-08-19 09:57:00 -10.87124          208.6608                   30.26583
# 2021-08-19 09:58:00 -10.69780          208.6575                   30.30819
# 2021-08-19 09:59:00 -10.02699          208.6554                   30.34490
# 2021-08-19 10:00:00 -10.24491          208.6541                   30.39573
#
#                      NO (ppb)  NO2 (ppb)  O3 (ppb)  PM10_logger (ug/m3)  \
# Date
# ...

# %% [markdown]
# ## Overview of raw logger data

# %%
# get a first look at the data
# %matplotlib widget
APVars=df1.columns 
df1[APVars].resample('1D').mean().plot(subplots=True, figsize=(7,20))
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df1[['O3 (ppb)']]['2021-04-12 00:00:00':'2021-08-23 08:00:00'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Clear all plots

# %%
plt.clf()

# %% [markdown]
# ## Importing and formatting eBam data (Northam site) <a id="exploringImportingeBam"></a>
# [Go to the top](#top)

# %% [markdown]
# EBAM errors
#
# - 0 = No Errors
# - 1 = Tape Break
# - 2 = Beta Count Test Failed
# - 4 = Delta Pressure/Vacuum Failed
# - 8 = Pressure Test Failed
# - 16 = Flow Less than 5 LPM for greater than 2 minutes
# - 32 = Nozzle Failed up/down movement
# - 64 = Internal Communication  Down
# - 128 = Low Battery
# - 256 = Delta T Alarm
# - 512 = Pump Over Temperature Alarm

# %% [markdown]
# ### Exploring the eBam data directory <a id="exploringeBam"></a>

# %%
sorted(os.listdir(Path(DataDir / 'Northam - Main AQMS/E-BAM Plus' )))
# Out:
# ['20200813',
#  '20200821',
#  '20200902',
#  '20200910',
#  '20200918',
#  '20200923',
#  '20200929',
#  '20201007',
#  '20201017',
#  '20201023',
#  '20201029',
#  '20201104',
#  '20201111',
#  '20201118',
#  '20201126',
#  '20201204',
#  '20201214',
#  '20210113',
#  '20210120',
#  '20210128',
#  '20210211',
#  '20210222',
#  '20210309',
#  '20210331',
#  '20210408',
#  '20210423',
#  '20210504',
#  '20210511',
#  '20210519',
#  '20210609',
#  '20210615',
#  '20210621',
#  '20210725',
#  '20210805',
#  '20210812',
#  '20210819',
#  '20210901']

# %%
#List the eBam files in the tree
sorted(lsR(Path(DataDir / 'Northam - Main AQMS/E-BAM Plus' ),'.CSV'))
# Out:
# ['/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/E-BAM Plus/20200821/PM10/Data.CSV',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/E-BAM Plus/20200821/PM2.5/Data.CSV',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/E-BAM Plus/20200902/PM10/Data.CSV',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/E-BAM Plus/20200902/PM2.5/Data.CSV',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/E-BAM Plus/20200910/PM10/Data.CSV',
#  '/home/roelof/Dropbox (NWU)/CRG_Projects/01_Research_Campaigns/Anglo_SA/01_Field Campaigns/Northam - Main AQMS/E-BAM Plus/20200910/PM2.5/Data.CSV',
# ...

# %% [markdown]
# ### Importing and formatting the PM10 eBam data <a id="importingeBam"></a>

# %%
PM10Variables=["Time","PM10 (ug/m3)","PM10_ConcHR (ug/m3)","PM10_Flow (lpm)","PM10_Wind_Speed (m/s)","PM10_Wind_Direction (Deg)","PM10_Ambient_Temperature (C)","PM10_Relative_Humidity (%)","PM10_BP (mmHg)","PM10_FT (C)","PM10_FRH (%)","PM10_Battery_Voltage (V)","PM10_PM (none)","PM10_Status (none)","Dummy"]

df2=pd.DataFrame()
for f in lsR(Path(DataDir / 'Northam - Main AQMS/E-BAM Plus' ),'.CSV'):
    if f.count("PM10") > 0:
        Data = readLogger(f,15)                                                                                                                                                                                                                                        
        dftmp = pd.read_csv(StringIO(Data), parse_dates=[0], index_col=0,names=PM10Variables)    
        if len(df2) == 0:
            df2 = dftmp
        else:
            df2 = df2.combine_first(dftmp)
            
df2.index.name="Date"
df2.drop(columns=['Dummy'],inplace=True)
df2=df2.resample('5min').first()


df2=df2.resample('1min').bfill(limit=5)
df2=df2[Northam_StartDate:]

# %% [markdown]
# #### View raw PM10 eBam data

# %%
# get a first look at the data
APVars=df2.columns 
df2[APVars].plot(subplots=True, figsize=(7,15))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Importing and formatting PM2.5 eBam data

# %%
PM25Variables=["Time","PM2.5 (ug/m3)","PM2.5_ConcHR (ug/m3)","PM2.5_Flow (lpm)","PM2.5_Wind_Speed (m/s)","PM2.5_Wind_Direction (Deg)","PM2.5_Ambient_Temperature (C)","PM2.5_Relative_Humidity (%)","PM2.5_BP (mmHg)","PM2.5_FT (C)","PM2.5_FRH (%)","PM2.5_Battery_Voltage (V)","PM2.5_PM (none)","PM2.5_Status (none)","Dummy"]

df3=pd.DataFrame()
for f in lsR(Path(DataDir / 'Northam - Main AQMS/E-BAM Plus' ),'.CSV'):
    if f.count("PM2.5") > 0:
        Data = readLogger(f,15)                                                                                                                                                                                                                                        
        dftmp = pd.read_csv(StringIO(Data), parse_dates=[0], index_col=0,names=PM25Variables)    
        if len(df3) == 0:
            df3 = dftmp
        else:
            df3 = df3.combine_first(dftmp)
df3.index.name="Date"
df3.drop(columns=['Dummy'],inplace=True)
df3=df3.resample('5min').first()

df3=df3.resample('1min').bfill(limit=5)
df3=df3[Northam_StartDate:]

# %%
# get a first look at the data
APVars=df3.columns 
df3[APVars].plot(subplots=True, figsize=(7,15))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Quality control

# %% [markdown]
# ## Set up QC variables

# %%
df1=df1.resample('1min').first() # logger
df2=df2.resample('1min').first() # PM10 ebam
df3=df3.resample('1min').first() # PM2.5 ebam

# %%
df1['Power_status']=0

df1['CO_status']=0
df1['CORaw']=df1['CO (ppm)']

df1['NO_status']=0
df1['NORaw']=df1['NO (ppb)']

df1['NO2_status']=0
df1['NO2Raw']=df1['NO2 (ppb)']

df1['O3_status']=0
df1['O3Raw']=df1['O3 (ppb)']

df1['PM10_logger_status']=0
df1['PM10_loggerRaw']=df1['PM10_logger (ug/m3)']

df1['PM2.5_logger_status']=0
df1['PM2.5_loggerRaw']=df1['PM2.5_logger (ug/m3)']

df1['SO2_status']=0
df1['SO2Raw']=df1['SO2 (ppb)']

# Not done at the moment
#df1['Rainfall (mm)']
#df1['Relative_Humidity (%)']
#df1['Temperature (degC)']
#df1['Wind_Direction (deg)']
#df1['Wind_Direction_Std (deg)']
#df1['Wind_Speed_Max (m/s)']
#df1['Wind_Speed_Std (m/s)']

# %% [markdown]
# ## Apply documented problems

# %%
# Update google sheet
reports, Reports = readSheet()

for index,row in Reports.iterrows():
    var='Which instrument failed?'
    sdate='When did the instrument start failing?'
    stime='What time did the instrument start to fail?'
    edate='When was the instrument failure fixed?'
    etime='What time was the instrument failure fixed?'
    
    S=pd.to_datetime("{} {}".format(row[sdate],row[stime]))
    E=pd.to_datetime("{} {}".format(row[edate],row[etime]))
    print(row[var],S,E)
    if row[var] in df1.columns:
        df1.loc[(df1.index >= S)&(df1.index <= E), row[var]] = nan
        
    if row[var].find("PM10") != -1:
        df2.loc[(df2.index >= S)&(df2.index <= E), row[var]] = nan
    if row[var].find("PM2.5") != -1:
        df3.loc[(df3.index >= S)&(df3.index <= E), row[var]] = nan
# Out:
# O3 (ppb) 2020-12-04 12:00:00 2020-12-14 13:15:00
# O3 (ppb) 2020-10-18 09:55:00 2020-11-08 07:53:00
# CO (ppm) 2020-07-15 00:00:00 2020-09-21 20:07:00
# CO (ppm) 2020-09-23 13:45:00 2020-09-23 14:03:00
# PM10 (ug/m3) 2020-12-31 03:00:00 2020-12-31 04:00:00
# PM2.5 (ug/m3) 2020-12-31 04:00:00 2020-12-31 05:00:00
# PM10 (ug/m3) 2021-01-07 06:00:00 2021-01-07 07:00:00
# PM2.5 (ug/m3) 2021-01-07 07:26:00 2021-01-07 07:28:00
# SO2 (ppb) 2020-08-15 23:00:00 2020-08-16 08:00:00
# SO2 (ppb) 2020-08-26 18:33:00 2020-08-27 16:04:00
# SO2 (ppb) 2020-09-17 11:00:00 2020-09-17 15:17:00
# SO2 (ppb) 2020-10-30 19:44:00 2020-10-30 19:46:00
# SO2 (ppb) 2020-11-11 15:17:00 2020-11-11 15:21:00
# SO2 (ppb) 2020-10-08 07:31:00 2020-10-08 07:32:00
# SO2 (ppb) 2020-10-16 08:06:00 2020-10-16 08:21:00
# SO2 (ppb) 2020-11-12 15:31:00 2020-11-12 15:33:00
# SO2 (ppb) 2021-01-13 12:30:00 2021-01-13 14:05:00
# PM2.5 (ug/m3) 2020-12-31 02:25:00 2020-12-31 04:35:00
# ...

# %%
df1[['SO2 (ppb)']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Line/battery voltage <a id="lbVqc"></a>

# %% [markdown]
# Plot the variables

# %%
fig, ax = plt.subplots()
df1[['Line_Voltage (V)']].plot(ax=ax)
df1[['Power_status']].plot(ax=ax, secondary_y=True, alpha=0.5)
# Out:
# <AxesSubplot:>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df1[df1['Power_status']==0][['Line_Voltage (V)']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#create flag variables
df1.loc[df1['Line_Voltage (V)']<190,'Power_status']=1
# 
df1.loc[(df1['Power_status']==0) & (df1['SO2 (ppb)'].isna()) & (df1['O3 (ppb)'].isna()) & (df1['NO2 (ppb)'].isna()) & (df1['PM10_logger (ug/m3)'].isna()),'Power_status']=2

# %% [markdown]
# Set all instruments on Eskom to missing if power is off

# %%
[i for i in df1.columns if i.find('Raw')<0 and i.find('status')<0]
# Out:
# ['Ambient_Temperature (degC)',
#  'Battery_Voltage (V)',
#  'CO (ppm)',
#  'Line_Voltage (V)',
#  'Logger_Temperature (degC)',
#  'NO (ppb)',
#  'NO2 (ppb)',
#  'O3 (ppb)',
#  'PM10_logger (ug/m3)',
#  'PM2.5_logger (ug/m3)',
#  'Rainfall (mm)',
#  'Relative_Humidity (%)',
#  'SO2 (ppb)',
#  'Temperature (degC)',
#  'Wind_Direction (deg)',
#  'Wind_Direction_Std (deg)',
#  'Wind_Speed_Max (m/s)',
#  'Wind_Speed_Std (m/s)']

# %%
PowerVars=['CO (ppm)',
            'NO (ppb)',
            'NO2 (ppb)',
            'O3 (ppb)',
            'PM10_logger (ug/m3)',
            'PM2.5_logger (ug/m3)',
            'SO2 (ppb)']

for v in PowerVars:
    df1.loc[df1['Power_status']>0,v]=nan
    df1.loc[df1['Power_status']>0,'{}_status'.format('CO (ppm)'.split()[0])]=1

# %% [markdown]
# ## Data quality control and assurance on eBam <a id="qcac"></a>
# [Go to the top](#top)

# %%
plt.clf()

# %%
@interact
def plotvar(type=['timeseries','diurnal'],var=['PM10 (ug/m3)','PM2.5 (ug/m3)']):
    if var.find('PM10')==0:
        df=df2
    if var.find('PM2.5')==0:
        df=df3
    if type=='timeseries':
        plottimeseries(df,var)
    elif type=='diurnal':
        plotdiurnal(df,var)
# Out:
# interactive(children=(Dropdown(description='type', options=('timeseries', 'diurnal'), value='timeseries'), Dro…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### PM10 eBam

# %%
# Set values missing if the instrument reported an error
df2.loc[df2['PM10_Status (none)']>0,'PM10 (ug/m3)']=nan
df3.loc[df3['PM2.5_Status (none)']>0,'PM2.5 (ug/m3)']=nan

df2.loc[df2['PM10 (ug/m3)']==99999,'PM10 (ug/m3)']=nan
df2.loc[df2['PM10 (ug/m3)']==99999,'PM10_Status (none)']=99999

df3.loc[df3['PM2.5 (ug/m3)']==99999,'PM2.5 (ug/m3)']=nan
df3.loc[df3['PM2.5 (ug/m3)']==99999,'PM2.5_Status (none)']=99999

df3.loc[df3['PM2.5 (ug/m3)']==40008,'PM2.5 (ug/m3)']=nan
df3.loc[df3['PM2.5 (ug/m3)']==40008,'PM2.5_Status (none)']=40008

df3.loc[df3['PM2.5 (ug/m3)']==80005,'PM2.5 (ug/m3)']=nan
df3.loc[df3['PM2.5 (ug/m3)']==80005,'PM2.5_Status (none)']=80005

df3.loc[df3['PM2.5 (ug/m3)']==20005,'PM2.5 (ug/m3)']=nan
df3.loc[df3['PM2.5 (ug/m3)']==20005,'PM2.5_Status (none)']=20005

df3.loc[df3['PM2.5 (ug/m3)']==20004,'PM2.5 (ug/m3)']=nan
df3.loc[df3['PM2.5 (ug/m3)']==20004,'PM2.5_Status (none)']=20004

# %% [markdown]
# check for specific values

# %%
df3[df3['PM2.5 (ug/m3)']>10000][['PM2.5 (ug/m3)','PM2.5_Status (none)']]
# Out:
#                      PM2.5 (ug/m3)  PM2.5_Status (none)
# Date
# 2021-02-15 15:01:00        40011.0                  0.0
# 2021-02-15 15:02:00        40011.0                  0.0
# 2021-02-15 15:03:00        40011.0                  0.0
# 2021-02-15 15:04:00        40011.0                  0.0
# 2021-02-15 15:05:00        40011.0                  0.0
# 2021-03-12 05:56:00        60005.0                  0.0
# 2021-03-12 05:57:00        60005.0                  0.0
# 2021-03-12 05:58:00        60005.0                  0.0
# 2021-03-12 05:59:00        60005.0                  0.0
# 2021-03-12 06:00:00        60005.0                  0.0
# 2021-03-13 11:56:00        60003.0                  0.0
# 2021-03-13 11:57:00        60003.0                  0.0
# 2021-03-13 11:58:00        60003.0                  0.0
# 2021-03-13 11:59:00        60003.0                  0.0
# 2021-03-13 12:00:00        60003.0                  0.0
# 2021-08-13 13:01:00        60010.0                  0.0
# ...

# %% [markdown]
# ### PM logged on the logger<a id="pmqc"></a>

# %% [markdown]
# Plot time series

# %%
@interact
def plotvar(y=['PM10_logger (ug/m3)','PM2.5_logger (ug/m3)']):
    plottimeseries(df1,y)
# Out:
# interactive(children=(Dropdown(description='y', options=('PM10_logger (ug/m3)', 'PM2.5_logger (ug/m3)'), value…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Plot diurnal variability

# %%
@interact
def plotvar(y=['PM10_logger (ug/m3)','PM2.5_logger (ug/m3)']):
    plotdiurnal(df1,y)
# Out:
# interactive(children=(Dropdown(description='y', options=('PM10_logger (ug/m3)', 'PM2.5_logger (ug/m3)'), value…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Set values missing if PM10 (ug/m3) values aren't 
df1.loc[df1['PM10_logger (ug/m3)']>=900,'PM10_logger (ug/m3)']=nan
df1.loc[df1['PM10_logger (ug/m3)']<0.001,'PM10_logger (ug/m3)']=nan
#Set values missing if PM2.5 (ug/m3) values aren't 
df1.loc[df1['PM2.5_logger (ug/m3)']>=900,'PM2.5_logger (ug/m3)']=nan
df1.loc[df1['PM2.5_logger (ug/m3)']<0.001,'PM2.5_logger (ug/m3)']=nan

# %%
df3['PM2.5 (ug/m3)']['2021'][df3['PM2.5 (ug/m3)']>800]
# Out:
# Date
# 2021-02-15 15:01:00    40011.0
# 2021-02-15 15:02:00    40011.0
# 2021-02-15 15:03:00    40011.0
# 2021-02-15 15:04:00    40011.0
# 2021-02-15 15:05:00    40011.0
# 2021-03-12 05:56:00    60005.0
# 2021-03-12 05:57:00    60005.0
# 2021-03-12 05:58:00    60005.0
# 2021-03-12 05:59:00    60005.0
# 2021-03-12 06:00:00    60005.0
# 2021-03-13 11:56:00    60003.0
# 2021-03-13 11:57:00    60003.0
# 2021-03-13 11:58:00    60003.0
# 2021-03-13 11:59:00    60003.0
# 2021-03-13 12:00:00    60003.0
# 2021-08-13 13:01:00    60010.0
# 2021-08-13 13:02:00    60010.0
# 2021-08-13 13:03:00    60010.0
# 2021-08-13 13:04:00    60010.0
# 2021-08-13 13:05:00    60010.0
# 2021-08-28 15:56:00    20015.0
# 2021-08-28 15:57:00    20015.0
# 2021-08-28 15:58:00    20015.0
# 2021-08-28 15:59:00    20015.0
# 2021-08-28 16:00:00    20015.0
# Name: PM2.5 (ug/m3), dtype: float64

# %%
#take a look at the cleaned data
fig, [ax1, ax2] = plt.subplots(2, 1, sharex=True, figsize=(7,6))
df1[['PM10_loggerRaw']].plot(ax=ax1)
df1[['PM10_logger (ug/m3)']].plot(ax=ax1)
df2[['PM10 (ug/m3)']].plot(ax=ax1)

df1[['PM2.5_loggerRaw']].plot(ax=ax2)
df1[['PM2.5_logger (ug/m3)']].plot(ax=ax2)
df3[['PM2.5 (ug/m3)']].plot(ax=ax2)
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, [ax1, ax2] = plt.subplots(2, 1, sharex=True, figsize=(7,6))
df1[['PM10_logger (ug/m3)']].plot(ax=ax1)
df1[['PM2.5_logger (ug/m3)']].plot(ax=ax2)
df1[['Line_Voltage (V)']].plot(ax=ax2)
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df3[['PM2.5 (ug/m3)']].describe(percentiles=[0.99])
# Out:
#        PM2.5 (ug/m3)
# count  316651.000000
# mean       23.042962
# std       449.995734
# min       -15.000000
# 50%        14.000000
# 99%       114.000000
# max     60010.000000

# %%
# Replace eBam data with those from logger for missing periods
startmis='2020/12/14 0:0'
endmis='2021/01/16 0:0'
df2.loc[(df2.index >= startmis) & (df2.index<=endmis),'PM10 (ug/m3)']=df2[['PM10 (ug/m3)']][startmis:endmis].combine_first(df1[['PM10_logger (ug/m3)']][startmis:endmis].rename(columns={'PM10_logger (ug/m3)':'PM10 (ug/m3)'})).values.flatten()
df3.loc[(df3.index >= startmis) & (df3.index<=endmis),'PM2.5 (ug/m3)']=df3[['PM2.5 (ug/m3)']][startmis:endmis].combine_first(df1[['PM2.5_logger (ug/m3)']]['2020/12/14 0:0':'2021/01/13 0:0'].rename(columns={'PM2.5_logger (ug/m3)':'PM2.5 (ug/m3)'})).values.flatten()

# %%
# Additional days when the data looks suspicious:

# negative values
#2020-10-07 (PM10_logger, PM2.5_logger)

# cut-off at 1000 ug/m3 (PM10_logger, PM2.5_logger)

# sporadic jumps to high values (PM2.5_logger)
#2020-10-07, 2020-10-08, 2020-10-14, 2020-10-15
#2020-11-06, 2020-11-11, 2020-11-12, 2020-11-13, 2020-11-16
#2020-12-12

# %%
df1.columns
# Out:
# Index(['Ambient_Temperature (degC)', 'Battery_Voltage (V)', 'CO (ppm)',
#        'Line_Voltage (V)', 'Logger_Temperature (degC)', 'NO (ppb)',
#        'NO2 (ppb)', 'O3 (ppb)', 'PM10_logger (ug/m3)', 'PM2.5_logger (ug/m3)',
#        'Rainfall (mm)', 'Relative_Humidity (%)', 'SO2 (ppb)',
#        'Temperature (degC)', 'Wind_Direction (deg)',
#        'Wind_Direction_Std (deg)', 'Wind_Speed_Max (m/s)',
#        'Wind_Speed_Std (m/s)', 'Power_status', 'CO_status', 'CORaw',
#        'NO_status', 'NORaw', 'NO2_status', 'NO2Raw', 'O3_status', 'O3Raw',
#        'PM10_logger_status', 'PM10_loggerRaw', 'PM2.5_logger_status',
#        'PM2.5_loggerRaw', 'SO2_status', 'SO2Raw', 'decimalhour'],
#       dtype='object')

# %% [markdown]
# ### SO2 <a id="SO2qc"></a>

# %%
#take a look at the data
#%matplotlib inline
# %matplotlib widget
df1[['SO2 (ppb)']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df1[['SO2 (ppb)', 'Line_Voltage (V)']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#create flag variable
df1['SO2 (ppb)']['2020-11-12'][df1['SO2 (ppb)']>10]
# Out:
# Series([], Freq: T, Name: SO2 (ppb), dtype: float64)

# %%
# Spike check
df1.loc[abs(df1['SO2 (ppb)']-df1['SO2 (ppb)'].shift())>30,'SO2 (ppb)']=nan

# %%
# Set upper and lower limits 
#is the upper limit ok here?
df1.loc[df1['SO2 (ppb)']>250,'SO2_status']=1
df1.loc[df1['SO2 (ppb)']>250,'SO2 (ppb)']=nan

df1.loc[df1['SO2 (ppb)']<-0.5, 'SO2_status']=1  # changed from -2 to 0
df1.loc[df1['SO2 (ppb)']<-0.5, 'SO2 (ppb)']=nan # changed from -2 to 0

# %%
#df1[['SO2Flag']].plot()

# %%
#create dataframes with those flagged days 
#df1_SO2Flag = df1.loc[df1['SO2Flag'] == 1]

# %%
# Additional days when the data looks suspicious

# Many negative values ...
# Upper limit cut off some data points

#from the old code
df1.loc['2020-08-11 08:02':'2020-08-11 17:41','SO2 (ppb)']=nan
df1.loc['2020-08-11 08:02':'2020-08-11 17:41','SO2Flag']=1
df1.loc['2020-08-11 08:02':'2020-08-11 17:41','SO2 (ppb)']=nan
df1.loc['2020-08-11 19:23':'2020-08-13 10:27','SO2Flag']=1
df1.loc['2020-08-26 14:36':'2020-08-26 14:37','SO2 (ppb)']=nan
df1.loc['2020-08-26 14:36':'2020-08-26 14:37','SO2Flag']=1
#df1['SO2 (ppb)']['2020-08-11 08:02':'2020-08-11 17:41']
df1.loc['2020-08-11 08:02':'2020-08-11 17:41','SO2 (ppb)']=nan

# %% [markdown]
# ### O3 <a id="O3qc"></a>

# %%
plottimeseries(df1,'O3 (ppb)')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#take a look at the data
@interact
def plotvar(type=['timeseries','diurnal']):
    var=['O3 (ppb)']
    if type=='timeseries':
        plottimeseries(df1,var)
    elif type=='diurnal':
        plotdiurnal(df1,var)
# Out:
# interactive(children=(Dropdown(description='type', options=('timeseries', 'diurnal'), value='timeseries'), Out…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#create flag variables 
df1['03Flag']=nan

# %%
df1.loc[df1['O3 (ppb)']>200,'O3 (ppb)']=nan
df1.loc[df1['O3 (ppb)']>200,'O3Flag']=1
df1.loc[df1['O3 (ppb)']<-10,'O3 (ppb)']=nan
df1.loc[df1['O3 (ppb)']<-10,'O3Flag']=1

# %%
#create dataframes with those flagged days 
df1_O3Flag = df1.loc[df1['O3Flag'] == 1]

# %%
# Additional days when the data looks suspicious
# Many negative values, scaling issure perhaps?

#df1.at['2020-08-11 08:02':'2020-08-11 08:04','O3Flag']=0

# %%
#take a look at the cleaned data
df1[['O3 (ppb)']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### NO <a id="NOqc"></a>

# %%
#take a look at the data
# %matplotlib widget
df1[['NO (ppb)','NO2 (ppb)', 'Line_Voltage (V)']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#create flag variables
df1['NOXFlag']=nan

# %%
def stuckValue(df,Var='PM2.5 (ug/m3)',diff=0.1,stuckNumber=3):                                                                                                                                                                                                                   
    print("In stuckValue:",Var,diff,stuckNumber)                                                                                                                                                                                                                                 
    df['diff']=(abs(df[Var]-df[Var].shift())>diff).astype(int)                                                                                                                                                                                                                   
    df['c'] = (df['diff'] != 0).cumsum()                                                                                                                                                                                                                                         
    df['a'] = (df['c'] == 0).astype(int)                                                                                                                                                                                                                                         
    df['streak'] = df.groupby( 'c' ).cumcount() + df['a']                                                                                                                                                                                                                        
    df.loc[df['streak'] > stuckNumber,Var] = np.nan                                                                                                                                                                                                                              
    df.drop(['streak', 'a','c','diff'], axis=1, inplace=True)                                                                                                                                                                                                                    

stuckValue(df1,Var='NO (ppb)',diff=0.1,stuckNumber=10) 
stuckValue(df1,Var='NO2 (ppb)',diff=0.1,stuckNumber=10)
# Out:
# In stuckValue: NO (ppb) 0.1 10
# In stuckValue: NO2 (ppb) 0.1 10

# %%
df1[['NO (ppb)','NO2 (ppb)']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df1.loc[df1['NO2 (ppb)']<1,'NO2_status']=1
df1.loc[df1['NO2 (ppb)']<1,['NO (ppb)','NO2 (ppb)']]=nan
df1.loc[df1['NO (ppb)']<1,'NO_status']=1
df1.loc[df1['NO (ppb)']<1,['NO (ppb)','NO2 (ppb)']]=nan

#upper maximum for NO or NO2?

# %%
#create dataframes with those flagged days  
#df1_NOXFlag = df1.loc[df1['NOX_status'] == 1]

# %%
# Additional days when the dloca looks suspicious

#sporadic neglocive values in both NO and NO2 dloca 

#sporadic high values in NO (ppb)
#2020-08-26
#2020-09-29
#2020-10-05
#2020-11-20
#2020-12-04

#from the old code, these days were removed - why?
df1.loc['2020-08-11 08:02':'2020-08-11 17:41','SO2 (ppb)']=nan
df1.loc['2020-08-11 08:02':'2020-08-11 17:41','SO2Flag']=1
df1.loc['2020-08-11 08:02':'2020-08-11 17:41','SO2 (ppb)']=nan
df1.loc['2020-08-11 19:23':'2020-08-13 10:27','SO2Flag']=1
df1.loc['2020-08-26 14:36':'2020-08-26 14:37','SO2 (ppb)']=nan
df1.loc['2020-08-26 14:36':'2020-08-26 14:37','SO2Flag']=1

# %% [markdown]
# ### CO <a id="coqc"></a>

# %%
#take a look at the data
# %matplotlib widget
df1[['CO (ppm)', 'Line_Voltage (V)']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#create flag variables
df1['COFlag']=nan

# %%
df1.loc[df1['CO (ppm)']<0,'COFlag']=1
df1.loc[df1['CO (ppm)']<0,['CO (ppm)']]=nan

#upper maximum for CO?

# %%
#create dataframes with those flagged days 
df1_COFlag = df1.loc[df1['COFlag'] == 1]

# %%
# Additional days when the data looks suspicious

#negative values removed for the following days:
#2020-07-30, 2020-07-31, 
#2020-08-11 - 2020-08-13
#2020-08-15 - 2020-08-16, 2020-08-17, 2020-08-20, 2020-08-21
#2020-08-27 - 2020-09-18
#2020-09-23

#extremely high value # should an upper limit be set for the data?
#2020-08-16
#2020-09-10
#2020-09-17
#2020-09-18

# %%
#take a look at the cleaned data
df1[['CO (ppm)', 'Line_Voltage (V)']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df1[['Line_Voltage (V)']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Wind speed and -direction <a id="wswd"></a>

# %%
#change wind speed to a float64/numeric
df1["Wind_Speed_Max (m/s)"] = pd.to_numeric(df1["Wind_Speed_Max (m/s)"], errors='coerce')

# %%
#take a look at the data
df1[['Wind_Direction (deg)']].plot()
df1[['Wind_Speed_Max (m/s)']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#create flag variables
df1['WSFlag']=nan
df1['WDFlag']=nan

# %%
df1.loc[df1['Wind_Speed_Max (m/s)']<0,'WSFlag']=1
df1.loc[df1['Wind_Speed_Max (m/s)']<0,['Wind_Speed_Max (m/s)']]=nan

# %%
df1.loc[df1['Wind_Direction (deg)']<=0,'WDFlag']=1
df1.loc[df1['Wind_Direction (deg)']<=0,['Wind_Direction (deg)']]=nan
df1.loc[df1['Wind_Direction (deg)']>360,'WDFlag']=1
df1.loc[df1['Wind_Direction (deg)']>360,['Wind_Direction (deg)']]=nan

# %%
#create dataframes with those flagged days 
df1_WSFlag = df1.loc[df1['WSFlag'] == 1]
df1_WDFlag = df1.loc[df1['WDFlag'] == 1]

# %%
df1_WDFlag.head()
# Out:
#                      Ambient_Temperature (degC)  Battery_Voltage (V)  \
# Date
# 2020-08-24 23:04:00                       19.15             12.04907
# 2020-09-02 23:36:00                       15.02             12.53687
# 2020-10-07 09:48:00                       20.28             12.03610
# 2020-10-07 09:49:00                       20.30             12.03518
# 2020-10-24 19:18:00                       22.27             12.95122
#
#                      CO (ppm)  Line_Voltage (V)  Logger_Temperature (degC)  \
# Date
# 2020-08-24 23:04:00       NaN          207.8392                   34.42812
# 2020-09-02 23:36:00       NaN          215.3071                   17.86819
# 2020-10-07 09:48:00  1.202058          211.4895                   25.80927
# 2020-10-07 09:49:00  1.218831          211.5398                   25.73057
# 2020-10-24 19:18:00  1.518704          205.3433                   38.69923
#
#                      NO (ppb)  NO2 (ppb)  O3 (ppb)  PM10_logger (ug/m3)  \
# Date
# ...

# %%
df1_WSFlag.head()
# Out:
# Empty DataFrame
# Columns: [Ambient_Temperature (degC), Battery_Voltage (V), CO (ppm), Line_Voltage (V), Logger_Temperature (degC), NO (ppb), NO2 (ppb), O3 (ppb), PM10_logger (ug/m3), PM2.5_logger (ug/m3), Rainfall (mm), Relative_Humidity (%), SO2 (ppb), Temperature (degC), Wind_Direction (deg), Wind_Direction_Std (deg), Wind_Speed_Max (m/s), Wind_Speed_Std (m/s), Power_status, CO_status, CORaw, NO_status, NORaw, NO2_status, NO2Raw, O3_status, O3Raw, PM10_logger_status, PM10_loggerRaw, PM2.5_logger_status, PM2.5_loggerRaw, SO2_status, SO2Raw, decimalhour, SO2Flag, 03Flag, O3Flag, NOXFlag, COFlag, WSFlag, WDFlag]
# Index: []
#
# [0 rows x 41 columns]

# %% [markdown]
# ## Merging and exporting the 3 data streams  <a id="mergeExportStreams"></a>
# [Go to the top](#top)

# %% [markdown]
# ### Merging the data <a id="mergeStreams"></a>

# %%
dfN=pd.concat([df1,df2,df3],axis=1)

# %%
dfN.describe()
# Out:
#        Ambient_Temperature (degC)  Battery_Voltage (V)       CO (ppm)  \
# count               528101.000000        528102.000000  163515.000000
# mean                    19.864785            13.403358       1.147427
# std                      7.793681             0.736392       1.143760
# min                     -4.805000            10.905130       0.000000
# 25%                     15.170000            12.847895       0.279548
# 50%                     20.570000            13.944770       0.927478
# 75%                     25.420000            13.966320       1.731256
# max                     39.850000            14.000600      24.002220
#
#        Line_Voltage (V)  Logger_Temperature (degC)       NO (ppb)  \
# count     528102.000000              528102.000000  246752.000000
# mean         199.108278                  30.055381       6.128379
# std           44.424537                   8.086220      43.980641
# min            0.000000                   5.096645       1.001900
# ...

# %%
dfN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 572481 entries, 2020-07-31 00:00:00 to 2021-09-01 13:20:00
# Freq: T
# Data columns (total 67 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Ambient_Temperature (degC)     528101 non-null  float64
#  1   Battery_Voltage (V)            528102 non-null  float64
#  2   CO (ppm)                       163515 non-null  float64
#  3   Line_Voltage (V)               528102 non-null  float64
#  4   Logger_Temperature (degC)      528102 non-null  float64
#  5   NO (ppb)                       246752 non-null  float64
#  6   NO2 (ppb)                      258309 non-null  float64
#  7   O3 (ppb)                       334495 non-null  float64
#  8   PM10_logger (ug/m3)            387400 non-null  float64
#  9   PM2.5_logger (ug/m3)           278842 non-null  float64
#  10  Rainfall (mm)                  528102 non-null  float64
# ...

# %%
(np.log(dfN[['PM10 (ug/m3)','PM2.5 (ug/m3)']].dropna().resample('1H').mean())).replace(-np.inf, np.nan).plot.hist(subplots=True,bins=20)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lastly, write the final dataframe to a csv file
dfN.to_csv(Path(FinalDataDir / 'Northam_data_level2_20210901.csv'.format()))

# %%
dfN[['CO (ppm)']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
APVars=['SO2 (ppb)', 'NO (ppb)', 'NO2 (ppb)', 'O3 (ppb)','CO (ppm)','PM10 (ug/m3)','PM2.5 (ug/m3)', 'PM10 (ug/m3)_logger', 'PM2.5 (ug/m3)_logger']
dfN[APVars].plot(subplots=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_893/2783948892.py in <module>
#       1 APVars=['SO2 (ppb)', 'NO (ppb)', 'NO2 (ppb)', 'O3 (ppb)','CO (ppm)','PM10 (ug/m3)','PM2.5 (ug/m3)', 'PM10 (ug/m3)_logger', 'PM2.5 (ug/m3)_logger']
# ----> 2 dfN[APVars].plot(subplots=True)
#
# ~/env/conda-python3-env/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/env/conda-python3-env/lib/python3.10/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# ...

# %%
MetVars=['Wind_Speed_Max (m/s)', 'Wind_Speed_Std (m/s)', 'Wind_Direction (deg)',
       'Wind_Direction_Std (deg)', 'Temperature (degC)',
       'Ambient_Temperature (degC)', 'Relative_Humidity (%)', 'Rainfall (mm)']
dfN[MetVars].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dfN[['PM10 (ug/m3)','PM2.5 (ug/m3)']].resample('1D').mean().describe(percentiles=[0.99])
# Out:
#        PM10 (ug/m3)  PM2.5 (ug/m3)
# count    259.000000     288.000000
# mean      70.498886      25.482716
# std       38.599683      47.628849
# min        6.402778       0.181944
# 50%       66.116783      17.294810
# 99%      156.108386     380.480404
# max      168.754067     464.908148

# %%
dfN[['PM10 (ug/m3)','PM2.5 (ug/m3)']].resample('1H').mean().plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Data visualizaton <a id="visualization"></a>

# %%
plt.clf()

# %%
# %matplotlib widget
@interact
def plotvar(y=list(dfN.select_dtypes('number').columns)):
    plottimeseries(dfN,y)
# Out:
# interactive(children=(Dropdown(description='y', options=('Ambient_Temperature (degC)', 'Battery_Voltage (V)', …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
@interact
def plotvar(y=list(dfN.select_dtypes('number').columns)):
    plotdiurnal(dfN,y)

# %% [markdown]
# ### Wind rose

# %%
dfN.columns
# Out:
# Index(['Ambient_Temperature (degC)', 'Battery_Voltage (V)', 'CO (ppm)',
#        'Line_Voltage (V)', 'Logger_Temperature (degC)', 'NO (ppb)',
#        'NO2 (ppb)', 'O3 (ppb)', 'PM10_logger (ug/m3)', 'PM2.5_logger (ug/m3)',
#        'Rainfall (mm)', 'Relative_Humidity (%)', 'SO2 (ppb)',
#        'Temperature (degC)', 'Wind_Direction (deg)',
#        'Wind_Direction_Std (deg)', 'Wind_Speed_Max (m/s)',
#        'Wind_Speed_Std (m/s)', 'Power_status', 'CO_status', 'CORaw',
#        'NO_status', 'NORaw', 'NO2_status', 'NO2Raw', 'O3_status', 'O3Raw',
#        'PM10_logger_status', 'PM10_loggerRaw', 'PM2.5_logger_status',
#        'PM2.5_loggerRaw', 'SO2_status', 'SO2Raw', 'decimalhour', 'SO2Flag',
#        '03Flag', 'O3Flag', 'NOXFlag', 'COFlag', 'WSFlag', 'WDFlag',
#        'PM10 (ug/m3)', 'PM10_ConcHR (ug/m3)', 'PM10_Flow (lpm)',
#        'PM10_Wind_Speed (m/s)', 'PM10_Wind_Direction (Deg)',
#        'PM10_Ambient_Temperature (C)', 'PM10_Relative_Humidity (%)',
# ...

# %%
#help(WindroseAxes)

# %%
# Define the settings for the windrose that is being created.
def plot_windrose(dfc,WD="Wind_Direction (deg)",WS="Wind_Speed_Max (m/s)"):                                                                                                                                                                                                                                                   
    
    # THe following two lines rounds the edges of the windrose bars to follow the bend in the circles, otherwise it is just a straight line.
    #plt.hist([0, 1])
    #plt.close()
    ax = WindroseAxes.from_ax()

    ax.bar(direction=dfc[WD], 
           var=dfc[WS],
           bins=np.arange(0, 8, 1), 
           normed=True, opening=0.95, 
           edgecolor='white', 
           cmap=cm.viridis, linewidth=0.5)
    #ax.set_yticks(np.arange(0, 60, step=5))
    #ax.set_yticklabels(np.arange(0, 60, step=5))
    
    ax.set_legend()
    ##ax.legend(loc='center left', numpoints=2, markerscale=0.5, markerfirst=True, 
    #          scatterpoints=None, scatteryoffsets=None, prop=None, fontsize=12.0, 
    #          borderpad=0.5, labelspacing=0.5, handlelength=2.0, handleheight=0.5, 
    #          handletextpad=1.0, borderaxespad=1.0, columnspacing=1.0, ncol=1, mode=None, 
    #          fancybox=True, shadow=True, title='Wind Speed (m/s)', title_fontsize=12.0, 
    #          framealpha=0.95, edgecolor='inherit', facecolor='inherit', 
    #          bbox_to_anchor=(1.1,0.5), bbox_transform=None, frameon=None, handler_map=None)
        
plot_windrose(dfN)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dfN.columns
# Out:
# Index(['Ambient_Temperature (degC)', 'Battery_Voltage (V)', 'CO (ppm)',
#        'Line_Voltage (V)', 'Logger_Temperature (degC)', 'NO (ppb)',
#        'NO2 (ppb)', 'O3 (ppb)', 'PM10_logger (ug/m3)', 'PM2.5_logger (ug/m3)',
#        'Rainfall (mm)', 'Relative_Humidity (%)', 'SO2 (ppb)',
#        'Temperature (degC)', 'Wind_Direction (deg)',
#        'Wind_Direction_Std (deg)', 'Wind_Speed_Max (m/s)',
#        'Wind_Speed_Std (m/s)', 'Power_status', 'CO_status', 'CORaw',
#        'NO_status', 'NORaw', 'NO2_status', 'NO2Raw', 'O3_status', 'O3Raw',
#        'PM10_logger_status', 'PM10_loggerRaw', 'PM2.5_logger_status',
#        'PM2.5_loggerRaw', 'SO2_status', 'SO2Raw', 'decimalhour', 'SO2Flag',
#        '03Flag', 'O3Flag', 'NOXFlag', 'COFlag', 'WSFlag', 'WDFlag',
#        'PM10 (ug/m3)', 'PM10_ConcHR (ug/m3)', 'PM10_Flow (lpm)',
#        'PM10_Wind_Speed (m/s)', 'PM10_Wind_Direction (Deg)',
#        'PM10_Ambient_Temperature (C)', 'PM10_Relative_Humidity (%)',
# ...

# %% [markdown]
# ## Data exploration and statistics <a id="explore"></a>

# %%
#has not been editted/updated

nMinutes=len(pd.date_range(start=dfN.index.values[0], end=dfN.index.values[-1], freq='1min'))
#pm10=dfN[['PM10_status','N']].groupby('PM10_status').count()/nMinutes*100
#pm25=dfN[['PM2.5_status','N']].groupby('PM2.5_status').count()/nMinutes*100
so2=dfN[['SO2_status']].groupby('SO2_status').count()/nMinutes*100
o3=dfN[['O3_status']].groupby('O3_status').count()/nMinutes*100
#nox=dfN[['NOX_status',]].groupby('NOX_status').count()/nMinutes*100
dfa=pd.concat([pm10,pm25,so2,o3,nox],axis=1)
dfa.columns=['PM10','PM2.5','SO2','O3','NOX']
dfa.index=['Data availability (%)','Instrument failures', 'Power failures']
dfa.round(1)
#df.round(dfa)
#with pd.option_context('precision', 0):
#    print(dfa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-dc22b91ff514> in <module>()
#       7 o3=dfN[['O3_status']].groupby('O3_status').count()/nMinutes*100
#       8 #nox=dfN[['NOX_status',]].groupby('NOX_status').count()/nMinutes*100
# ----> 9 dfa=pd.concat([pm10,pm25,so2,o3,nox],axis=1)
#      10 dfa.columns=['PM10','PM2.5','SO2','O3','NOX']
#      11 dfa.index=['Data availability (%)','Instrument failures', 'Power failures']
#
# NameError: name 'pm10' is not defined

# %% [markdown]
# ## Source Apportionment Met Data Spring

# %%
df1.head()
# Out:
#                      Ambient_Temperature (degC)  Battery_Voltage (V)  \
# Date
# 2020-07-31 00:00:00                       7.459             12.55329
# 2020-07-31 00:01:00                       7.425             12.55054
# 2020-07-31 00:02:00                       7.393             12.55283
# 2020-07-31 00:03:00                       7.371             12.55512
# 2020-07-31 00:04:00                       7.347             12.55649
#
#                      CO (ppm)  Line_Voltage (V)  Logger_Temperature (degC)  \
# Date
# 2020-07-31 00:00:00       NaN          215.5085                   18.07811
# 2020-07-31 00:01:00       NaN          215.5085                   18.18467
# 2020-07-31 00:02:00       NaN          215.5085                   18.29538
# 2020-07-31 00:03:00       NaN          215.4749                   18.40664
# 2020-07-31 00:04:00       NaN          215.3071                   18.47009
#
#                      NO (ppb)  NO2 (ppb)  O3 (ppb)  PM10_logger (ug/m3)  \
# Date
# ...

# %%
df1.resample('1H').mean()

# %%
df1.dtypes

# %%
dfM= df1.loc['2020-10-08 22:00:00' : '2020-10-16 22:00:00']

# %%
dfM.head()

# %%
dfM.info()

# %%
dfM.info()

# %%
dfM.resample('12H', offset='1H').mean()

# %%
dfM.head()

# %%
dfM.to_csv ('Data/NT_MET.csv', index = True, header=True)

# %%
matplotlib.projections.get_projection_names()

# %%
# Define the settings for the windrose that is being created.
def plot_windrose(dfc,WD="Wind_Direction (deg)",WS="Wind_Speed_Max (m/s)"):                                                                                                                                                                                                                                                   
    
    # THe following two lines rounds the edges of the windrose bars to follow the bend in the circles, otherwise it is just a straight line.
    #plt.hist([0, 1])
    #plt.close()
    ax = WindroseAxes.from_ax()

    ax.bar(direction=dfc[WD], 
           var=dfc[WS],
           bins=np.arange(0, 8, 1), 
           normed=True, opening=0.95, 
           edgecolor='white', 
           cmap=cm.viridis, linewidth=0.5)
    ax.set_xticklabels(['N','NE','E','SE','S','SW','W','NW'])
    ax.set_theta_zero_location("N")
    ax.set_theta_direction(-1)
    #ax.set_yticks(np.arange(0, 60, step=5))
    #ax.set_yticklabels(np.arange(0, 60, step=5))
    
    ax.set_legend()
    ##ax.legend(loc='center left', numpoints=2, markerscale=0.5, markerfirst=True, 
    #          scatterpoints=None, scatteryoffsets=None, prop=None, fontsize=12.0, 
    #          borderpad=0.5, labelspacing=0.5, handlelength=2.0, handleheight=0.5, 
    #          handletextpad=1.0, borderaxespad=1.0, columnspacing=1.0, ncol=1, mode=None, 
    #          fancybox=True, shadow=True, title='Wind Speed (m/s)', title_fontsize=12.0, 
    #          framealpha=0.95, edgecolor='inherit', facecolor='inherit', 
    #          bbox_to_anchor=(1.1,0.5), bbox_transform=None, frameon=None, handler_map=None)
    
plot_windrose(dfM)

# %%
plot_windrose(dfM)

# %%
dfMS= pd.read_csv('AngloSa_NT_MET.csv')

# %%
dfMS.head()
